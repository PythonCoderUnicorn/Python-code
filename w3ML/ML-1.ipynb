# %% [markdown]
# # w3 Machine Learning

# %%
# https://www.w3schools.com/python/python_ml_getting_started.asp

# %%
import pandas as pd
import numpy as np

np.random.seed(34)

# %%
cars = pd.DataFrame(
    {'Carname': ['BMW','Volvo','VW','VW','Ford','Tesla','Toyota'],# 7
     'Color': ['Red','Blue','Black','White','White','Black','Blue'], #7
     'Age': np.random.randint(1,20,7),
     'Speed': np.random.randint(80, 113,7),
    },
    columns=['Carname','Color','Age','Speed'] 
)
cars
# Out:
#   Carname  Color  Age  Speed
# 0     BMW    Red    2     94
# 1   Volvo   Blue   11    109
# 2      VW  Black   10     98
# 3      VW  White    5    109
# 4    Ford  White    4    105
# 5   Tesla  Black    6    109
# 6  Toyota   Blue   12    100

# %% [markdown]
# ## DataTypes
#
# - Numerical
#     - Discrete Data = integer (number of vehicles)
#     - Continuous = infinite value (prices, size of item)
# - Categorical
#     - values can't be measured against each other (colors, Y/N)
# - Ordinal
#     - values that can be measured against each other (grades: A > C)

# %%
# Standard deviation is a number that describes how spread out the values are.
#  low std = most of the numbers are close to the mean (average) value.
#  high std = the values are spread out over a wider range.
cars.Speed.describe()
# Out:
# count      7.000000
# mean     103.428571
# std        6.133437
# min       94.000000
# 25%       99.000000
# 50%      105.000000
# 75%      109.000000
# max      109.000000
# Name: Speed, dtype: float64

# %%
cars.Speed.mean()
# Out:
# 103.42857142857143

# %%
# the value that appears most often
cars.Speed.mode()
# Out:
# 0    109
# dtype: int64

# %%
speed = [86,87,88,86,87,85,86]
x = np.mean(speed) 
print(x)
x2 = np.std(speed) 
print(x2)
x3 = np.var(speed)
print(x3) 
# std: Meaning that most of the values are within the range of 0.9 
# from the mean value, which is 86.4. Symbol is Sigma

# Variance is another number that indicates how spread out the values are.
#  Symbol is Sigma squared

#  percentiles
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31] 
a = np.percentile(ages, 75) 
print('75% = ',a) 
a2 = np.percentile(ages, 90) 
print('90% = ',a2)  
# meaning that 75% of the people are 43 or younger.
# meaning that 90% of the people are 61 or younger.
# Out:
# 86.42857142857143
# 0.9035079029052513
# 0.8163265306122449
# 75% =  43.0
# 90% =  61.0

# %%
# create an array of 250 float numbers between 0 - 5
x = np.random.uniform(0.0, 5.0, 250)

print(x)
# Out:
# [3.24236392 4.34684373 3.04517852 4.03996409 4.13255665 1.35841667
#  4.1823822  1.4127068  0.69154301 3.57360137 2.36268304 2.7829424
#  1.92787787 4.7057333  0.40595338 4.58633742 0.78467213 2.22073743
#  1.06053022 0.87346579 2.57399026 4.46448769 4.61840534 4.17989276
#  2.49828646 4.10481955 4.6719408  3.97405937 2.30792551 1.76344903
#  0.54296213 4.92388266 0.75529136 1.39206065 3.49564772 3.23851369
#  1.11768272 4.00924268 2.56056155 0.39331189 0.17079881 2.83075654
#  0.7483678  1.20616511 0.16742864 3.27962218 4.27214017 0.99876896
#  4.03526244 0.37723244 3.18017193 4.15421596 1.45760769 2.37847576
#  0.87012186 4.76484083 0.20547976 4.25701739 4.19701083 4.80620041
#  0.45511665 4.81654968 0.56058526 0.22228339 3.72391023 4.32691844
#  4.67900318 3.14963467 1.65692013 2.35359999 4.01064649 4.71402021
#  0.81912961 3.09341    0.11663366 0.39367067 4.30055433 4.85695629
#  4.46043487 3.05520511 1.1193145  2.49431601 4.8567743  0.93803098
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background') 
plt.figure(figsize=(15,10))
x = np.random.uniform(0.0, 5.0, 250)

plt.hist(x, 5) # 5 bars

plt.show()

# %%
# normal data distribution
plt.style.use('dark_background') 
plt.figure(figsize=(15,10))

#                   mean, std, num of values
x = np.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()

# %%
#  scatterplot

# Age of car
x = cars.Age

# speed of car
y = cars.Speed

plt.style.use('dark_background')
plt.figure(figsize=(15,10))
plt.xlabel("Age of car", fontsize=20)
plt.ylabel("Car Speed", fontsize=20)

plt.scatter(x,y)
plt.show()

# %%
x = np.random.normal(5.0, 1.0, 1000)
y = np.random.normal(10.0, 2.0, 1000)

plt.style.use('dark_background')
plt.figure(figsize=(15,10))
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## **Linear Regression**
#
# - regression is used when you try to find the relationship between variables.
# - Linear regression uses the relationship between the data-points to draw a straight line through all them. This line can be used to predict future values.

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.style.use('dark_background')
plt.figure(figsize=(15,10))
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### **R** for relationship
# - relationship between x and y is a must
# - the relationship (coefficient of correlation) = r
# - value of r ranges 0 to 1 (0= no relationship, 1= 100% relationship)

# %%
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

print(r) 
# there is a weak relationship, can use Linear Regression
# Out:
# -0.758591524376155

# %%
#  predict future values, predict speed of 10 yr old car
def myfunc(x):
    return slope * x + intercept

# %%
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
    return slope * x + intercept

speed = myfunc(10)

print(speed)
# Out:
# 85.59308314937454

# %%
#  scipy linear regression line
from scipy import stats
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

# Create a function that uses the slope and intercept values to return a new value. 
# This new value represents where on the y-axis the corresponding x value will be placed:
def myfunc(x):
    return slope * x + intercept

# Run each value of the x array through the function. 
# This will result in a new array with new values for the y-axis:
mymodel = list(map(myfunc, x))

plt.style.use('dark_background')
plt.figure(figsize=(15,10))
plt.scatter(x, y)

# Draw the line of linear regression:
plt.plot(x, mymodel)

plt.show()

# %%
#  r = .013 tells you that there is a very weak relationship and not suited for Linear Regression

# %% [markdown]
# ### **Polynomial** Regression
#
# - If your data points clearly will not fit a linear regression (a straight line through all data points), it might be ideal for polynomial regression.

# %%
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

plt.style.use('dark_background')
plt.figure(figsize=(15,10))
plt.xlabel("Hours of day", fontsize=20)
plt.ylabel("Speed at tollbooth", fontsize=20)
plt.scatter(x, y) 
plt.show()

# %%
#  polynomial regression
import numpy as np
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = np.poly1d(np.polyfit(x, y, 3))

myline = np.linspace(1, 22, 100)

plt.style.use('dark_background')
plt.figure(figsize=(15,10))
plt.xlabel("Hours of day", fontsize=20)
plt.ylabel("Speed at tollbooth", fontsize=20)
plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# ### **R-Squared** relationship
#
# - if there's no relationship the polynomial rehression can't be used to predict anything
# - r-squared values range 0 to 1 (1= 100%, 0= no relationship)

# %%
import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x))) 

# the value of r-square score shows a strong relationship and can make predictions
# Out:
# 0.9432150416451025

# %% [markdown]
# predict the speed of a car that passes the toll at around 17:00 hrs
# - use mymodel

# %%
import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

speed = mymodel(17)
print('predicted speed = {}'.format(speed))
# Out:
# predicted speed = 88.87331269697991

# %% [markdown]
# a bad fit for polynomial regression

# %%
import numpy
import matplotlib.pyplot as plt

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(2, 95, 100)


plt.style.use('dark_background')
plt.figure(figsize=(15,10))
plt.xlabel("Hours of day", fontsize=20)
plt.ylabel("Speed at tollbooth", fontsize=20) 
# plt.show()
plt.scatter(x, y)
plt.plot(myline, mymodel(myline))




print(r2_score(y, mymodel(x)))
# Out:
# 0.009952707566680652

# %% [markdown]
# ### **Multiple Regression**
# - try to predict a value based on 2+ variables

# %%
import pandas as pd

df = pd.read_csv('carsCO2.csv') 
df.head()
# Out:
#       Carname       Model  Volume  Weight  CO2  Age  Speed
# 0      Toyota        Aygo    1000     790   99   12    103
# 1  Mitsubishi  Space Star    1200    1160   95    7     85
# 2       Skoda      Citigo    1000     929   95   18    107
# 3        Fiat         500     900     865   90    9    100
# 4        Mini      Cooper    1500    1140  105    6     85

# %% [markdown]
# We can predict the CO2 emission of a car based on the size of the engine, but with multiple regression we can throw in more variables, like the weight of the car, to make the prediction more accurate.
#
#
# - independent variable = X (capital X)
# - dependent variable = y

# %%
# car weight and engine volume size
X = df[['Weight','Volume']]
# dependent variable CO2, what is being predicted
y = df.CO2

# %% [markdown]
# import sklearn to use linear_model and fit()

# %%
from sklearn import linear_model

LinReg = linear_model.LinearRegression() 
LinReg.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# we now have a regression object that are ready to predict CO2 values based on a car's weight and volume:

# %%
# predict the CO2 emission of a car where: 
# the weight is 2300kg, and the volume is 1300cm3:
predictedCO2 = LinReg.predict([[2300, 1300]])
pred = float(predictedCO2)

print('CO2 prediction: {:.2f}g'.format(pred))
# Out:
# CO2 prediction: 107.21g

# %% [markdown]
# We have predicted that a car with a weight of 2300 kg, and 1.3 liter engine, will release approximately 107 grams of CO2 for every kilometer it drives.

# %% [markdown]
# **Coefficient**
# - coefficient is a factor that describes the relationship with an unknown variable.
# - we can ask for the coefficient value of weight against CO2, and for volume against CO2. The answer(s) we get tells us what would happen if we increase, or decrease, one of the independent values.

# %%
print(LinReg.coef_)
# Out:
# [0.00755095 0.00780526]

# %%
print('weight coeff: ',LinReg.coef_[0]) 
print('volume coeff: ',LinReg.coef_[1])
# Out:
# weight coeff:  0.00755094727030069
# volume coeff:  0.007805257527747127

# %% [markdown]
# - These values tell us that if the weight increase by 1kg, the CO2 emission increases by 0.00755095g.
#
# -  if the engine size (Volume) increases by 1 cm3, the CO2 emission increases by 0.00780526 g.

# %% [markdown]
# prediction of CO2 @ volume: 1300, weight: 2300kg,  CO2 emission = 107g
# - what if weight was 1000kg more ?

# %%
predictedCO2 = LinReg.predict([[3300, 1300]])
pred = float(predictedCO2)

print('CO2 prediction: {:.2f}g'.format(pred))
# Out:
# CO2 prediction: 114.76g

# %% [markdown]
# - We have predicted that a car with 1.3 liter engine, and a weight of 3300 kg, will release approximately 115 grams of CO2 for every kilometer it drives.
#
# - Which shows that the coefficient of 0.00755095 is correct:
#     - 107.2087328 + (1000 * 0.00755095) = 114.75968

# %%
df.describe()
avg = np.mean(df) 
print('mean:\n',avg)
s = np.std(df)
print('\n std:\n',s)
# Out:
# mean:
#  Volume    1611.111111
# Weight    1292.277778
# CO2        102.027778
# Age          9.722222
# Speed       98.277778
# dtype: float64
#
#  std:
#  Volume    383.534569
# Weight    238.737374
# CO2         7.350307
# Age         5.226062
# Speed       8.681433
# dtype: float64

# %% [markdown]
# ### **Scaling Features**
#
# - When your data has different values, and even different measurement units, it can be difficult to compare them. We can **scale data into new values that are easier to compare.**
# - the **volume column** contains values in *liters instead of cm3* (1.0 instead of 1000).
# - need to scale BOTH volume and weight
# - Formula: z = (x - mu)/ std
#     - z= new value, x= original value, mu= mean, std= standard deviation
#     - Weight: z = (790 - 1292.23) / 238 = -2.1
#     - *divide values by 1000 to = 1.0, 383.53 / 1000 = .383*
#     - Volume: z = (1.0 - 1.61) / 0.38 = -1.59
# - can now compare: -2.1 with -1.59
# - USE **sklearn StandardScalar()** to transform data sets

# %%
import pandas
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

X = df[['Weight', 'Volume']]

scaledX = scale.fit_transform(X)

print(scaledX)
# Out:
# [[-2.10389253 -1.59336644]
#  [-0.55407235 -1.07190106]
#  [-1.52166278 -1.59336644]
#  [-1.78973979 -1.85409913]
#  [-0.63784641 -0.28970299]
#  [-1.52166278 -1.59336644]
#  [-0.76769621 -0.55043568]
#  [ 0.3046118  -0.28970299]
#  [-0.7551301  -0.28970299]
#  [-0.59595938 -0.0289703 ]
#  [-1.30803892 -1.33263375]
#  [-1.26615189 -0.81116837]
#  [-0.7551301  -1.59336644]
#  [-0.16871166 -0.0289703 ]
#  [ 0.14125238 -0.0289703 ]
#  [ 0.15800719 -0.0289703 ]
#  [ 0.3046118  -0.0289703 ]
#  [-0.05142797  1.53542584]
#  [-0.72580918 -0.0289703 ]
#  [ 0.14962979  1.01396046]
#  [ 1.2219378  -0.0289703 ]
#  [ 0.5685001   1.01396046]
#  [ 0.3046118   1.27469315]
#  [ 0.51404696 -0.0289703 ]
#  [ 0.51404696  1.01396046]
#  [ 0.72348212 -0.28970299]
#  [ 0.8281997   1.01396046]
#  [ 1.81254495  1.01396046]
#  [ 0.96642691 -0.0289703 ]
#  [ 1.72877089  1.01396046]
#  [ 1.30990057  1.27469315]
#  [ 1.90050772  1.01396046]
#  [-0.23991961 -0.0289703 ]
#  [ 0.40932938 -0.0289703 ]
# ...

# %% [markdown]
# When the data set is scaled, you will have to use the scale when you predict values:
# - Predict the CO2 emission from a 1.3 liter car that weighs 2300 kilograms:

# %%
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
scale = StandardScaler() 

X = df[['Weight', 'Volume']]
y = df['CO2']

scaledX = scale.fit_transform(X)

regr = linear_model.LinearRegression()
regr.fit(scaledX, y)

scaled = scale.transform([[2300, 1.3]])

predictedCO2 = regr.predict([scaled[0]])
f = float(predictedCO2)
print('predicted CO2: ',f)
# Out:
# predicted CO2:  97.07204484763704

# %% [markdown]
# ## Train  / Test Model for Evaluation

# %% [markdown]
# Our data set illustrates 100 customers in a shop, and their shopping habits.
# - x axis represents the number of minutes before making a purchase.
# - y axis represents the amount of money spent on the purchase.

# %%
import numpy
import matplotlib.pyplot as plt
numpy.random.seed(2)

x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

plt.style.use('dark_background')
plt.figure(figsize=(15,10))
plt.xlabel("Minutes before Purchase", fontsize=20)
plt.ylabel("Amount of $ spent", fontsize=20)
plt.scatter(x, y)
plt.show()

# %% [markdown]
# split into Train / Test data. 80% Train | 20% Test

# %%
train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

# %%
#  display Training
plt.style.use('dark_background')
plt.figure(figsize=(15,10))
plt.xlabel("Minutes before Purchase", fontsize=20)
plt.ylabel("Amount of $ spent", fontsize=20)
plt.title('Train Data', fontsize=20)
plt.scatter(train_x, train_y)
plt.show()

# %%
# display test data
plt.style.use('dark_background')
plt.figure(figsize=(15,10))
plt.xlabel("Minutes before Purchase", fontsize=20)
plt.ylabel("Amount of $ spent", fontsize=20)
plt.title('Test Data', fontsize=20)
plt.scatter(test_x, test_y)
plt.show()

# %% [markdown]
# ## Fit the Data set
# - let's use a polynomial regression line

# %%
import numpy
import matplotlib.pyplot as plt
numpy.random.seed(2)

x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))

myline = numpy.linspace(0, 6, 100)


plt.style.use('dark_background')
plt.figure(figsize=(15,10))
plt.xlabel("Minutes before Purchase", fontsize=20)
plt.ylabel("Amount of $ spent", fontsize=20)
plt.title('Polynomial Regression', fontsize=20)
plt.scatter(train_x, train_y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# a customer at the 6 minute mark would likely spend around $200, could be a sign of overfitting
# - use R-squared to see relationship
#     - sklearn module has a method called r2_score() that will help us find this relationship.
#
#
# -  measure the relationship between the minutes a customer stays in the shop and how much money they spend.
#
# - **How well does my training data fit in a polynomial regression?**

# %%
import numpy
from sklearn.metrics import r2_score
numpy.random.seed(2)

x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))

r2 = r2_score(train_y, mymodel(train_x))
print(r2)
# Out:
# 0.79886455446298

# %% [markdown]
# 0.798 shows a good relationship in the training data. Now use testing data

# %%
numpy.random.seed(2) 
x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))

r2 = r2_score(test_y, mymodel(test_x))

print(r2)
# Out:
# 0.8086921460343566

# %% [markdown]
# 0.8086 value shows good relationship in test data. We can now predict future values
#
#
# **How much money will a buying customer spend, if they stay in the shop for 5 minutes?**

# %%
print('predicted spending at 5 minutes: ${:.2f}'.format(mymodel(5)) )
# Out:
# predicted spending at 5 minutes: $22.88

# %% [markdown]
# ## Decision Tree
#
# - A Decision Tree is a Flow Chart, and can help you make decisions based on previous experience.
# - In the example, a person will try to decide if they should go to a comedy show or not.

# %%
df = pd.read_csv('decisionTree.csv')
df.head()
# Out:
#    Age  Experience  Rank Nationality  Went
# 0   34          24     4          UK     0
# 1   61          24     6         USA     0
# 2   28          12     5         CAN     0
# 3   49          21     6         CAN     0
# 4   30          25     5         AUS     1

# %%
#  use the map() function to convert strings to numeric values
d = {'UK':0,'USA':1,'CAN':2,'AUS':3} 
df['Nationality'] = df['Nationality'].map(d) 
df.head()
# Out:
#    Age  Experience  Rank  Nationality  Went
# 0   34          24     4            0     0
# 1   61          24     6            1     0
# 2   28          12     5            2     0
# 3   49          21     6            2     0
# 4   30          25     5            3     1

# %% [markdown]
# Then we have to separate the feature columns from the target column.
#
#
# - The **feature columns** are the columns that we try to predict from
# - the **target column** is the column with the values we try to **predict.**

# %%
features = ['Age', 'Experience', 'Rank', 'Nationality']

X = df[features]
y = df['Went']

# print(X)
# print(y)

X
# Out:
#     Age  Experience  Rank  Nationality
# 0    34          24     4            0
# 1    61          24     6            1
# 2    28          12     5            2
# 3    49          21     6            2
# 4    30          25     5            3
# 5    64          18     5            0
# 6    27          17     7            0
# 7    38          13     5            1
# 8    57          21     6            2
# 9    70          28     6            1
# 10   40          23     6            0
# 11   23           3     4            2
# 12   27          12     6            2

# %%
y
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1
# 5     0
# 6     0
# 7     1
# 8     1
# 9     1
# 10    1
# 11    0
# 12    1
# Name: Went, dtype: int64

# %% [markdown]
# DECISION TREE

# %% [raw]
# import pandas
# from sklearn import tree
# import pydotplus
# from sklearn.tree import DecisionTreeClassifier
# import matplotlib.pyplot as plt
# import matplotlib.image as pltimg
# import graphviz as graph  # <<-- fails to work
#
#
# dtree = DecisionTreeClassifier()
# dtree = dtree.fit(X, y)
# data = tree.export_graphviz(dtree, out_file=None, feature_names=features)
# graph = pydotplus.graph_from_dot_data(data)
# graph.write_png('mydecisiontree.png')
#
# img=pltimg.imread('mydecisiontree.png')
# imgplot = plt.imshow(img)
# plt.show()

# %% [markdown]
# ### RANK
#
# - **Rank** <= 6.5 means that every comedian with a rank of 6.5 or lower will follow the True arrow (to the left), and the rest will follow the False arrow (to the right).
#
# - **gini** = 0.497 refers to the quality of the split, and is always a number between 0.0 and 0.5, where 0.0 would mean all of the samples got the same result, and 0.5 would mean that the split is done exactly in the middle.
#
# - **samples** = 13 means that there are 13 comedians left at this point in the decision, which is all of them since this is the first step.
#
# - **value** = [6, 7] means that of these 13 comedians, 6 will get a "NO", and 7 will get a "Went".

# %% [markdown]
# ### Gini
# - There are many ways to split the samples, we use the GINI method in this tutorial.
# - The Gini method uses this formula:
#     - <code>Gini = 1 - (x/n)^2 - (y/n)^2 </code>
#
# - Where x is the number of positive answers("Went"), n is the number of samples, and y is the number of negative answers ("NO"), which gives us this calculation:
#     - <code>1 - (7 / 13)^2 - (6 / 13)^2 = 0.497</code>

# %%
# https://www.w3schools.com/python/python_ml_decision_tree.asp
